# %%
import numpy as np # for performing linear algebra 
import pandas as pd # to read csv files
import matplotlib.pyplot as plt # to pot different types of graphs
import seaborn as sns

# %%
data = pd.read_csv('countries of the world.csv')

# %%
data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
# calculating the number of rows and columns data
data.shape
# Out:
# (227, 20)

# %%
# total number of columns
data.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
# Gives a view of data 
data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
#data types  inforamation
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Country                               227 non-null object
# Region                                227 non-null object
# Population                            227 non-null int64
# Area (sq. mi.)                        227 non-null int64
# Pop. Density (per sq. mi.)            227 non-null object
# Coastline (coast/area ratio)          227 non-null object
# Net migration                         224 non-null object
# Infant mortality (per 1000 births)    224 non-null object
# GDP ($ per capita)                    226 non-null float64
# Literacy (%)                          209 non-null object
# Phones (per 1000)                     223 non-null object
# Arable (%)                            225 non-null object
# Crops (%)                             225 non-null object
# Other (%)                             225 non-null object
# ...

# %%
# Correlation between data
data.corr()
# Out:
#                     Population  Area (sq. mi.)  GDP ($ per capita)
# Population            1.000000        0.469985           -0.039324
# Area (sq. mi.)        0.469985        1.000000            0.072185
# GDP ($ per capita)   -0.039324        0.072185            1.000000

# %%
#Visulization of Correlation by graph
plt.subplots(figsize=(4,4))
sns.heatmap(data.corr(), annot=True, linewidths=0.1)
plt.show()

# %%
# description of dataset
data.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
# Renaming the dataset for the ease of comfort
data.rename(columns={"Area (sq. mi.)": "Area", "Pop. Density (per sq. mi.)":"Pop_Density",
                        "Coastline (coast/area ratio)":"Coastline","Net migration":"Net_migration",
                        "Infant mortality (per 1000 births)":"Infant_mortality","GDP ($ per capita)":"GDP",
                        "Literacy (%)":"Literacy","Phones (per 1000)":"Phones","Arable (%)":"Arable",
                        "Crops (%)":"Crops","Other (%)":"Other"},inplace = True)

# %%
data.head(100)
# Out:
#                   Country                               Region  Population  \
# 0            Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                Albania   EASTERN EUROPE                          3581655
# 2                Algeria   NORTHERN AFRICA                        32930091
# 3         American Samoa   OCEANIA                                   57794
# 4                Andorra   WESTERN EUROPE                            71201
# 5                 Angola   SUB-SAHARAN AFRICA                     12127071
# 6               Anguilla               LATIN AMER. & CARIB           13477
# 7      Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8              Argentina               LATIN AMER. & CARIB        39921833
# 9                Armenia                  C.W. OF IND. STATES      2976372
# 10                 Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Country             227 non-null object
# Region              227 non-null object
# Population          227 non-null int64
# Area                227 non-null int64
# Pop_Density         227 non-null object
# Coastline           227 non-null object
# Net_migration       224 non-null object
# Infant_mortality    224 non-null object
# GDP                 226 non-null float64
# Literacy            209 non-null object
# Phones              223 non-null object
# Arable              225 non-null object
# Crops               225 non-null object
# Other               225 non-null object
# Climate             205 non-null object
# Birthrate           224 non-null object
# Deathrate           223 non-null object
# Agriculture         212 non-null object
# Industry            211 non-null object
# Service             212 non-null object
# dtypes: float64(1), int64(2), object(17)
# ...

# %%
#counting total number of null values
missing = data.isnull().sum()
missing
# Out:
# Country              0
# Region               0
# Population           0
# Area                 0
# Pop_Density          0
# Coastline            0
# Net_migration        3
# Infant_mortality     3
# GDP                  1
# Literacy            18
# Phones               4
# Arable               2
# Crops                2
# Other                2
# Climate             22
# Birthrate            3
# Deathrate            4
# Agriculture         15
# Industry            16
# Service             15
# dtype: int64

# %%
# filling  the missing values by using fillna method, will fill Nan values with mean of columns
data.fillna(data.mean(),inplace=True)
data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
 # calculating total number of null values in each row
data.isnull().sum()
# Out:
# Country              0
# Region               0
# Population           0
# Area                 0
# Pop_Density          0
# Coastline            0
# Net_migration        3
# Infant_mortality     3
# GDP                  0
# Literacy            18
# Phones               4
# Arable               2
# Crops                2
# Other                2
# Climate             22
# Birthrate            3
# Deathrate            4
# Agriculture         15
# Industry            16
# Service             15
# dtype: int64

# %%
# Replacing NaN with 0
data.fillna({'Net_migration':0,'Infant_mortality':0,'Literacy': 0,'Phones':0,'Arable':0,'Crops':0,'Other':0,'Climate':0},inplace=True)

# %%
data.isnull().sum()
# Out:
# Country              0
# Region               0
# Population           0
# Area                 0
# Pop_Density          0
# Coastline            0
# Net_migration        0
# Infant_mortality     0
# GDP                  0
# Literacy             0
# Phones               0
# Arable               0
# Crops                0
# Other                0
# Climate              0
# Birthrate            3
# Deathrate            4
# Agriculture         15
# Industry            16
# Service             15
# dtype: int64

# %%
data.describe()
# Out:
#          Population          Area           GDP
# count  2.270000e+02  2.270000e+02    227.000000
# mean   2.874028e+07  5.982270e+05   9689.823009
# std    1.178913e+08  1.790282e+06  10026.881258
# min    7.026000e+03  2.000000e+00    500.000000
# 25%    4.376240e+05  4.647500e+03   1900.000000
# 50%    4.786994e+06  8.660000e+04   5600.000000
# 75%    1.749777e+07  4.418110e+05  15700.000000
# max    1.313974e+09  1.707520e+07  55100.000000

# %%
# mean of region
group = data.groupby("Region")
group.mean()
# Out:
#                                        Population          Area           GDP
# Region
# ASIA (EX. NEAR EAST)                 1.317137e+08  8.248826e+05   8053.571429
# BALTICS                              2.394991e+06  5.833833e+04  11300.000000
# C.W. OF IND. STATES                  2.334013e+07  1.841737e+06   4000.000000
# EASTERN EUROPE                       9.992893e+06  9.601850e+04   9808.333333
# LATIN AMER. & CARIB                  1.248499e+07  4.565352e+05   8682.222222
# NEAR EAST                            1.219177e+07  2.722241e+05  10456.250000
# NORTHERN AFRICA                      2.690119e+07  1.003148e+06   6164.970501
# NORTHERN AMERICA                     6.633446e+07  4.356494e+06  26100.000000
# OCEANIA                              1.577698e+06  4.057053e+05   8247.619048
# SUB-SAHARAN AFRICA                   1.469484e+07  4.772825e+05   2323.529412
# WESTERN EUROPE                       1.415500e+07  1.325171e+05  27046.428571

# %%
#plotting bar_graph on the basis number of countries in a region
# plt.xticks(rotation=45):- this is used to slant the name  of the countries on the axis by 45 degree, so that the name does not overlap

plt.figure(figsize=(10,7))
sns.barplot(x=region.index,y=region.values)
plt.xticks(rotation=45)
plt.ylabel('Number of countries')
plt.xlabel('Region')
plt.title('Number of Countries by REGİON',color = 'red',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Number of Countries by REGİON')

# %%
sns.barplot(x="Region",y="GDP",data=data)
plt.xticks(rotation=90)
plt.title("GDP BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'GDP BY REGİON')

# %%
#Population more than 100 million
data[data["Population"]>100000000]

# %%
sns.barplot(x="Region",y="Population",data=data)
plt.xticks(rotation=90)
plt.title("Population BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Population BY REGİON')

# %%
data.Pop_Density = data.Pop_Density.str.replace(",",".").astype(float)

# %%
sns.barplot(x="Region",y="Pop_Density",data=data)
plt.xticks(rotation=90)
plt.title("Population Density BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Population BY REGİON')

# %%
data["Deathrate"]
# Out:
# 0      20,34
# 1       5,22
# 2       4,61
# 3       3,27
# 4       6,25
# 5       24,2
# 6       5,34
# 7       5,37
# 8       7,55
# 9       8,23
# 10      6,68
# 11      7,51
# 12      9,76
# 13      9,75
# 14      9,05
# 15      4,14
# 16      8,27
# 17      8,67
# 18     14,02
# 19     10,27
# 20      5,72
# 21     12,22
# 22      7,74
# 23      12,7
# 24      7,53
# 25      8,27
# 26      29,5
# 27      6,17
# 28      4,42
# 29      3,45
#        ...
# 197     4,81
# 198     6,48
# 199     8,25
# 200    16,39
# 201     7,04
# 202     9,83
# 203     5,28
# 204    10,57
# 205     5,13
# 206     5,97
# 207      8,6
# 208     4,21
# 209     7,11
# 210    12,24
# 211    14,39
# 212      4,4
# 213    10,13
# 214     8,26
# 215     9,05
# 216     7,84
# 217     7,82
# 218     4,92
# 219     6,22
# 220     6,43
# 221      NaN
# 222     3,92
# 223      NaN
# 224      8,3
# 225    19,93
# 226    21,84
# Name: Deathrate, Length: 227, dtype: object

# %%
#removing commas and converting to float
data.Deathrate = data.Deathrate.str.replace(",",".").astype(float)
data["Deathrate"]
# Out:
# 0      20.34
# 1       5.22
# 2       4.61
# 3       3.27
# 4       6.25
# 5      24.20
# 6       5.34
# 7       5.37
# 8       7.55
# 9       8.23
# 10      6.68
# 11      7.51
# 12      9.76
# 13      9.75
# 14      9.05
# 15      4.14
# 16      8.27
# 17      8.67
# 18     14.02
# 19     10.27
# 20      5.72
# 21     12.22
# 22      7.74
# 23     12.70
# 24      7.53
# 25      8.27
# 26     29.50
# 27      6.17
# 28      4.42
# 29      3.45
#        ...
# 197     4.81
# 198     6.48
# 199     8.25
# 200    16.39
# 201     7.04
# 202     9.83
# 203     5.28
# 204    10.57
# 205     5.13
# 206     5.97
# 207     8.60
# 208     4.21
# 209     7.11
# 210    12.24
# 211    14.39
# 212     4.40
# 213    10.13
# 214     8.26
# 215     9.05
# 216     7.84
# 217     7.82
# 218     4.92
# 219     6.22
# 220     6.43
# 221      NaN
# 222     3.92
# 223      NaN
# 224     8.30
# 225    19.93
# 226    21.84
# Name: Deathrate, Length: 227, dtype: float64

# %%
#removing commas and converting to float
data.Birthrate = data.Birthrate.str.replace(",",".").astype(float)
data["Birthrate"]
# Out:
# 0      46.60
# 1      15.11
# 2      17.14
# 3      22.46
# 4       8.71
# 5      45.11
# 6      14.17
# 7      16.93
# 8      16.73
# 9      12.07
# 10     11.03
# 11     12.14
# 12      8.74
# 13     20.74
# 14     17.57
# 15     17.80
# 16     29.80
# 17     12.71
# 18     11.16
# 19     10.38
# 20     28.84
# 21     38.85
# 22     11.40
# 23     33.65
# 24     23.30
# 25      8.77
# 26     23.08
# 27     16.56
# 28     14.89
# 29     18.79
#        ...
# 197    27.76
# 198    12.56
# 199    32.65
# 200    37.71
# 201    13.87
# 202    37.01
# 203    25.37
# 204    12.90
# 205    15.52
# 206    16.62
# 207    27.61
# 208    21.84
# 209    22.18
# 210    47.35
# 211     8.82
# 212    18.96
# 213    10.71
# 214    14.14
# 215    13.91
# 216    26.36
# 217    22.72
# 218    18.71
# 219    16.86
# 220    13.96
# 221      NaN
# 222    31.67
# 223      NaN
# 224    42.89
# 225    41.00
# 226    28.01
# Name: Birthrate, Length: 227, dtype: float64

# %%
sns.boxplot(x="Region",y="Deathrate",data=data)
plt.xticks(rotation=90)
plt.title("Deathrate BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Deathrate BY REGİON')

# %%
sns.boxplot(x="Region",y="Birthrate",data=data)
plt.xticks(rotation=90)
plt.title("Birthrate BY REGİON",color="red")
# Out:
# Text(0.5, 1.0, 'Birthrate BY REGİON')

# %%
#removing commas and converting to float
data.Industry = data.Industry.str.replace(",",".").astype(float)

# %%
sns.barplot(x="Region",y="Industry",data=data)
plt.xticks(rotation=90)
plt.title("Industry BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Industry BY REGİON')

# %%
#removing commas and converting to float
data.Literacy = data.Literacy.replace(",",".").astype(float)

# %%
sns.boxplot(x="Region",y="Literacy",data=data)
plt.xticks(rotation=90)
plt.title("Literacy BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Literacy BY REGİON')

# %%
#Visualizing correlation with heat map
f,ax = plt.subplots(figsize=(18, 16))
sns.heatmap(data.corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)

# %%
#removing commas and converting to float
data.Phones = data.Phones.replace(",",".").astype(float)
data.Service = data.Service.replace(",",".").astype(float)

# %%
sns.lmplot(x="GDP",y="Phones",data=data,height=10)
sns.lmplot(x="GDP",y="Service",data=data,height=10)

# %%
#removing commas and converting to float
data.Net_migration = data.Net_migration.str.replace(",",".").astype(float)

# %%
sns.boxplot(x="Region",y="Net_migration",data=data)
plt.xticks(rotation=90)
plt.title("Net Migration BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Net Migration BY REGİON')

# %%
#GDP is key value. As we can see, there are positive correlation between "Phones" and "Service".

# %%
#removing commas and converting to float
data.Crops = data.Crops.str.replace(",",".").astype(float)

# %%
sns.lmplot(x="GDP",y="Crops",data=data,height=10)

# %%
#removing commas and converting to float
data.Agriculture = data.Agriculture.str.replace(",",".").astype(float)

# %%
sns.lmplot(x="GDP",y="Agriculture",data=data,height=10)

# %%
#More money more phones, more sevices, more agriculture, more crops.

# %%
#removing commas and converting to float
data.Area = data.Area.replace(",",".").astype(float)

# %%
sns.barplot(x="Region",y="Area",data=data)
plt.xticks(rotation=90)
plt.title("Area BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Area BY REGİON')

# %%
#removing commas and converting to float
data.Coastline = data.Coastline.str.replace(",",".").astype(float)

# %%
sns.barplot(x="Region",y="Coastline",data=data)
plt.xticks(rotation=90)
plt.title("Coastline BY REGİON",color="blue")
# Out:
# Text(0.5, 1.0, 'Coastline BY REGİON')
